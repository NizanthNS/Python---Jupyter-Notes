# %% [markdown]
# # Converting Data Types

# %%
num_int = 7

type(num_int)
# Out:
# int

# %%
num_str = '7'

type(num_str)
# Out:
# str

# %%
num_str_con = int(num_str)

type(num_str_con)
# Out:
# int

# %%
num_sum = num_int + num_str_con

print(num_sum)
# Out:
# 14

# %%
x = 7
y = 'Stars'

print(x,y)
# Out:
# 7 Stars

# %%
list_type = [1,2,3,4]

type(list_type)
# Out:
# list

# %%
type(tuple(list_type))
# Out:
# tuple

# %%
list_type1 = [1,2,3,4,1,2,4,5,1]

# %%
type(set(list_type1))
# Out:
# set

# %%
dict_type = {'name' : 'Niz', 'Age' : 27, 'Hair' : 'Black'}

type(dict_type)
# Out:
# dict

# %%
dict_type.items()
# Out:
# dict_items([('name', 'Niz'), ('Age', 27), ('Hair', 'Black')])

# %%
dict_type.values()
# Out:
# dict_values(['Niz', 27, 'Black'])

# %%
dict_type.keys()
# Out:
# dict_keys(['name', 'Age', 'Hair'])

# %%
list(dict_type.keys())

type(list(dict_type.keys()))
# Out:
# list

# %%
long_str = 'I like Pizaa'

list(long_str)
# Out:
# ['I', ' ', 'l', 'i', 'k', 'e', ' ', 'P', 'i', 'z', 'a', 'a']
