# %% [markdown]
# # HTML and Inspecting a Web Page
#     <html>
#     <head>
#     <title> Web Page </title>
#     </head>
#
#     <body>
#         <h1> Hello World</h1>
#         <p><b> Hello!<b><p>
#     </body>
#     </html>
#
#     https://www.scrapethissite.com/pages/forms/
