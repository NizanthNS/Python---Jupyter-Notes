# %% [markdown]
# # Variables

# %%
x = 22
print(x)
# Out:
# 22

# %%
type(x)
# Out:
# int

# %%
y = "Let's go"
print(y)
# Out:
# Let's go

# %%
type(y)
# Out:
# str

# %%
y = "Go"

Y = "Let's go"

print(y)
# Out:
# Go

# %%
x,y,z = "Pizza","Burger","Soda"

print(x)
print(y)
print(z)
# Out:
# Pizza
# Burger
# Soda

# %%
x = y = z = "Pizaa"

print(x)
print(y)
print(z)
# Out:
# Pizaa
# Pizaa
# Pizaa

# %%
food = ["Pizza","Burger","Soda"]

x,y,z = food

print(x)
print(y)
print(z)
# Out:
# Pizza
# Burger
# Soda

# %%
food_list = ["Fried Chicken", "Waffles", "Shawarma", "Cake"]

a,b,c,d = food_list

print(a)
print(b)
print(c)
print(d)
# Out:
# Fried Chicken
# Waffles
# Shawarma
# Cake

# %%
# Camel Case

# Test Variable Case

testVariablCase = "Vanilla Swirl"

# %%
# Pascal Case

# Test Variable Case

TestVariablCase = "Vanilla Swirl"

# %%
# Snake Case

# Test Variable Case

test_variabl_case = "Vanilla Swirl"

# %%
# DO list

testvar = "Vanilla Swirl"
test_var = "Vanilla Swirl"
_test_var = "Vanilla Swirl"
testVar = "Vanilla Swirl"
TestVar = "Vanilla Swirl"
testVar2 = "Vanilla Swirl"

# %%
# Not DO list

2testvar = "Vanilla Swirl"
test-var = "Vanilla Swirl"
test var2 = "Vanilla Swirl"
test, Var2 = "Vanilla Swirl"

# %%
x = "Pizza is my favorite" + "."

print(x)
# Out:
# Pizza is my favorite.

# %%
y = 5 + 8

print(y)
# Out:
# 13

# %%
x = "Pizza"
y = " is"
z = " my favorite"

print(x+y+z)
# Out:
# Pizza is my favorite

# %%
x = 4
y = 6
z = 8

print(x+y+z)
# Out:
# 18

# %%
x = "Pizza"
y = 2

print(x,y)
# Out:
# Pizza 2
